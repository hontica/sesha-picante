# %%
import math_operations as mo

# %%
mo.basic_math.add(1,100)
# Out:
# 101

# %%
sum_all = mo.basic_math.multiply(1,100)
print(sum_all)
# Out:
# 100

# %%
product_all = mo.basic_math.multiply(1,100)
print(product_all)
# Out:
# 100

# %%
x = list(range(0,10))
y = list(range(0,10))

# %%
mo.plotting.plot_graph(x=x,y=y)
# Out:
# <Axes: title={'center': 'CHEE 412-005'}, xlabel='products', ylabel='moola'>
